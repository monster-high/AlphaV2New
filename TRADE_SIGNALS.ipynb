# %%
# Import packages
import TS_Custom
from TS_Custom import *


    
def getStrategyResult(symbol):
    #for symbol in symbol_list :
    try:
        #print (datetime.now().strftime('%H:%M'))            
        # get price history from tradestation
        mins = 1

        #bars are set to 600 so that ATR for UTBot Buy is accurate
        barsBack=int(barssince7am(mins))
        if (barsBack <= 75):
            barsBack = 75
    
        df = getPriceHistory_TS(symbol,str(barsBack), str(mins))
        df = getHA(df)

        atr = df['ATR']
        
        df = Supertrend(df, 10, 1)
        #df = UTBot_Sell(df,2,1,False)
        #df = UTBot_Buy(df,2,300,False)
        
        
        #retrieve keys
        last_key = atr.keys()[-1]
        previous_key = atr.keys()[-2]
        previous_key_2 = atr.keys()[-3]
        
        
        # Strategy Code
        #variables
        datetime_now = datetime.now().strftime('%Y-%m-%d %H-%M-%S')
        strategy = 'Supertrend'
        tf="MIN"
        candles="HA"

        # Buy Stock          
        
        if (
            #((df['utbot_signal_BUY'][previous_key] == "BUY") and (df['ST_Lowerband'][previous_key]> 0)) or \
            ((df['ST_Upperband'][previous_key] > 0) and (df['ST_Lowerband'][last_key]> 0))) :
            
            print("ALL CONDITIONS FOR BUY STOCK MET FOR ", symbol)
            # get quote from tradestation
            quote = getQuote(symbol)
            bidPrice = round((quote['Bid']), 2)
            askPrice = round((quote['Ask']), 2)
            
            winsound.Beep(4000, 500)
            addTradeSignalsOutputtoDB(datetime_now, str(symbol),str(mins) + " "+ str(tf) + " " + str(candles),bidPrice,askPrice,strategy,"BUY")
            


        # Sell Short Stock   
        if (
            #((df['utbot_signal_SELL'][previous_key] == "SELL") and (df['ST_Upperband'][previous_key]> 0)) or \
            ((df['ST_Lowerband'][previous_key] > 0) and (df['ST_Upperband'][last_key]> 0))) :
        

            print("ALL CONDITIONS FOR SELL STOCK MET FOR ", symbol)
            # get quote from tradestation
            quote = getQuote(symbol)
            bidPrice = round((quote['Bid']), 2)
            askPrice = round((quote['Ask']), 2)
            
            winsound.Beep(4000, 500)
            addTradeSignalsOutputtoDB(datetime_now, str(symbol), str(mins) + " "+ str(tf) + " " + str(candles),bidPrice,askPrice,strategy,"SELL")
            

    except Exception as e:
        print(symbol)
        traceback.print_exc()
        print(e)
        
while True:        
        
    now = datetime.now()
    today800=now.replace(hour=7,minute=0,second=0,microsecond=0)
    today1500=now.replace(hour=23,minute=0,second=0,microsecond=0)
    #if (True) :
    if (now > today800 and now < today1500 ) :

        #symbol_list1 = ['AAPL'] 


        symbol_list1 = pd.read_csv('tickers1.csv', header=None)[0].tolist()
        print(symbol_list1)
        # Time starts from here
        start = time.time()


        with concurrent.futures.ThreadPoolExecutor(max_workers=len(symbol_list1)) as executor:
            executor.map(getStrategyResult,symbol_list1)

        # Total time calculated
        print(now, ' - symbol_list1 took ', time.time()-start, 'seconds.')

        print("**************************************************************")
        time.sleep(40)


        '''

        buystrategy,sellstrategy,buylong,buyshort,buycall,buyput = get_Trade_Signals_fromDB()
        symbol_list2 = pd.read_csv('tickers2.csv', header=None)[0].tolist()
        print(symbol_list2)


        # Time starts from here
        start = time.time()


        with concurrent.futures.ThreadPoolExecutor(max_workers=len(symbol_list2)) as executor:            
            executor.map(getStrategyResult,symbol_list2)

        # Total time calculated
        print(now, ' - symbol_list2 took ', time.time()-start, 'seconds.')

        print("**************************************************************")
        time.sleep(30)



        buystrategy,sellstrategy,buylong,buyshort,buycall,buyput = get_Trade_Signals_fromDB()
        symbol_list3 = pd.read_csv('tickers3.csv', header=None)[0].tolist()
        print(symbol_list3)

        # Time starts from here
        start = time.time()        

        with concurrent.futures.ThreadPoolExecutor(max_workers=len(symbol_list3)) as executor:
            #print(threading.currentThread().ident)
            executor.map(getStrategyResult,symbol_list3)

        # Total time calculated
        print(now, ' - symbol_list3 took ', time.time()-start, 'seconds.')

        print("**************************************************************")
        time.sleep(30)
            
       '''
# Out:
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AAPL
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  LABU
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 11:34:59.031040  - symbol_list1 took  2.3995261192321777 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:35:41.452564  - symbol_list1 took  1.4990794658660889 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:36:22.960315  - symbol_list1 took  1.4241256713867188 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 11:37:04.390545  - symbol_list1 took  1.880842685699463 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# 2022-12-06 11:37:46.278058  - symbol_list1 took  2.455488920211792 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  SPY
# ALL CONDITIONS FOR SELL STOCK MET FOR  NFLX
# 2022-12-06 11:38:28.744979  - symbol_list1 took  2.0787193775177 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:39:10.827130  - symbol_list1 took  1.6309964656829834 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:39:52.467003  - symbol_list1 took  1.3521668910980225 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:40:33.825247  - symbol_list1 took  1.5780327320098877 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
# 2022-12-06 11:41:15.414982  - symbol_list1 took  1.9808440208435059 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
# 2022-12-06 11:41:57.405898  - symbol_list1 took  2.1899824142456055 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 11:42:39.608136  - symbol_list1 took  2.2706027030944824 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  AMD
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 11:43:21.894504  - symbol_list1 took  1.6579804420471191 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:44:03.559788  - symbol_list1 took  1.4700953960418701 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  LABU
# 2022-12-06 11:44:45.035347  - symbol_list1 took  2.2096431255340576 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:45:27.255615  - symbol_list1 took  1.5370562076568604 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:46:08.802949  - symbol_list1 took  1.3621621131896973 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:46:50.171634  - symbol_list1 took  1.272216558456421 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:47:31.449616  - symbol_list1 took  1.3631625175476074 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AMZN
# 2022-12-06 11:48:12.825354  - symbol_list1 took  2.159668445587158 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AMZN
# 2022-12-06 11:48:54.992055  - symbol_list1 took  1.9630670547485352 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:49:36.967959  - symbol_list1 took  1.4041361808776855 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:50:18.389993  - symbol_list1 took  1.5980160236358643 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:50:59.997261  - symbol_list1 took  1.376155138015747 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  PLUG
# 2022-12-06 11:51:41.383199  - symbol_list1 took  2.077723264694214 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:52:23.467739  - symbol_list1 took  1.3981404304504395 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMD
# 2022-12-06 11:53:04.873146  - symbol_list1 took  2.0857176780700684 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMD
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# 2022-12-06 11:53:46.964222  - symbol_list1 took  1.6908786296844482 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:54:28.673018  - symbol_list1 took  1.5630369186401367 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:55:10.251632  - symbol_list1 took  1.8488643169403076 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:55:52.118430  - symbol_list1 took  1.470095157623291 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:56:33.600865  - symbol_list1 took  1.3731558322906494 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:57:14.981773  - symbol_list1 took  1.4101336002349854 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:57:56.409406  - symbol_list1 took  1.5790297985076904 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 11:58:37.997513  - symbol_list1 took  1.5020759105682373 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 11:59:19.509911  - symbol_list1 took  1.9148244857788086 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# 2022-12-06 12:00:01.437817  - symbol_list1 took  1.7219409942626953 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AMD
# ALL CONDITIONS FOR BUY STOCK MET FOR  NVDA
# 2022-12-06 12:00:43.165355  - symbol_list1 took  1.9742200374603271 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 12:01:25.148730  - symbol_list1 took  2.1706602573394775 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:02:07.327035  - symbol_list1 took  1.492081642150879 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:02:48.830950  - symbol_list1 took  1.4511127471923828 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# 2022-12-06 12:03:30.288276  - symbol_list1 took  1.4980669021606445 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMD
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# ALL CONDITIONS FOR SELL STOCK MET FOR  MSFT
# 2022-12-06 12:04:11.801418  - symbol_list1 took  2.191668748855591 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  MSFT
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMD
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  PLUG
# ALL CONDITIONS FOR SELL STOCK MET FOR ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
#  SHOP
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 12:04:54.004914  - symbol_list1 took  2.096708059310913 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:05:36.108936  - symbol_list1 took  1.4121296405792236 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:06:17.536039  - symbol_list1 took  1.4840879440307617 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:06:59.034793  - symbol_list1 took  1.5160667896270752 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:07:40.567505  - symbol_list1 took  1.87685227394104 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NFLX
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 12:08:22.449055  - symbol_list1 took  2.030750036239624 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:09:04.490716  - symbol_list1 took  1.5180673599243164 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  AMD
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 12:09:46.013259  - symbol_list1 took  1.5610377788543701 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:10:27.581045  - symbol_list1 took  1.6629788875579834 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# 2022-12-06 12:11:09.258296  - symbol_list1 took  2.5384373664855957 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  AMZN
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 12:11:51.803113  - symbol_list1 took  2.3198606967926025 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:12:34.129604  - symbol_list1 took  1.4920823574066162 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:13:15.639046  - symbol_list1 took  1.464099407196045 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:13:57.120411  - symbol_list1 took  1.7229409217834473 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  CCL
# ALL CONDITIONS FOR BUY STOCK MET FOR  NVDA
# ALL CONDITIONS FOR BUY STOCK MET FOR  AMD
# 2022-12-06 12:14:38.856656  - symbol_list1 took  2.1349592208862305 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AAPL
# 2022-12-06 12:15:21.006894  - symbol_list1 took  2.5079915523529053 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:16:03.520034  - symbol_list1 took  1.4860870838165283 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:16:45.009022  - symbol_list1 took  1.533057451248169 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  SPY
# ALL CONDITIONS FOR BUY STOCK MET FOR  TSLA
# ALL CONDITIONS FOR BUY STOCK MET FOR  AAPL
# ALL CONDITIONS FOR BUY STOCK MET FOR  NFLX
# 2022-12-06 12:17:26.552892  - symbol_list1 took  2.4135148525238037 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# 2022-12-06 12:18:08.973320  - symbol_list1 took  2.3161063194274902 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  MSFT
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# 2022-12-06 12:18:51.297898  - symbol_list1 took  2.180420398712158 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:19:33.484161  - symbol_list1 took  1.4221224784851074 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:20:14.920693  - symbol_list1 took  1.4740955829620361 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:20:56.403889  - symbol_list1 took  1.4411146640777588 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  SPY
# 2022-12-06 12:21:37.854454  - symbol_list1 took  1.6060113906860352 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:22:19.472910  - symbol_list1 took  1.3831489086151123 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NFLX
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# 2022-12-06 12:23:00.866938  - symbol_list1 took  2.4115138053894043 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:23:43.285464  - symbol_list1 took  1.5950188636779785 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMD
# ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
# 2022-12-06 12:24:24.883770  - symbol_list1 took  2.193650245666504 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:25:07.084927  - symbol_list1 took  1.518066167831421 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 12:25:48.617399  - symbol_list1 took  2.3555047512054443 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  COIN
# 2022-12-06 12:26:30.977732  - symbol_list1 took  1.678968906402588 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 12:27:12.661131  - symbol_list1 took  1.8748528957366943 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 12:27:54.549726  - symbol_list1 took  1.965672254562378 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:28:36.523536  - symbol_list1 took  1.6070172786712646 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# 2022-12-06 12:29:18.139204  - symbol_list1 took  2.2166378498077393 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:30:00.368031  - symbol_list1 took  1.7469267845153809 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# 2022-12-06 12:30:42.135883  - symbol_list1 took  1.7089476585388184 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:31:23.854831  - symbol_list1 took  1.5930204391479492 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# ALL CONDITIONS FOR SELL STOCK MET FOR  PLUG
# 2022-12-06 12:32:05.458207  - symbol_list1 took  2.047738552093506 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  PLUG
# 2022-12-06 12:32:47.515636  - symbol_list1 took  1.9997687339782715 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMZN
# 2022-12-06 12:33:29.525243  - symbol_list1 took  2.226627826690674 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:34:11.769552  - symbol_list1 took  1.4660959243774414 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:34:53.242045  - symbol_list1 took  1.5330586433410645 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AMD
# ALL CONDITIONS FOR BUY STOCK MET FOR  NVDA
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# ALL CONDITIONS FOR BUY STOCK MET FOR  AAPL
# 2022-12-06 12:35:34.790830  - symbol_list1 took  2.775330066680908 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  SPY
# ALL CONDITIONS FOR BUY STOCK MET FOR  MSFT
# 2022-12-06 12:36:17.571349  - symbol_list1 took  1.7299363613128662 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  TSLA
# ALL CONDITIONS FOR BUY STOCK MET FOR  MSFT
# ALL CONDITIONS FOR BUY STOCK MET FOR  LABU
# 2022-12-06 12:36:59.314119  - symbol_list1 took  2.394503593444824 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  TSLA
# ALL CONDITIONS FOR BUY STOCK MET FOR  SHOP
# 2022-12-06 12:37:41.718777  - symbol_list1 took  2.082719564437866 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# ALL CONDITIONS FOR BUY STOCK MET FOR  CCL
# ALL CONDITIONS FOR BUY STOCK MET FOR  SHOP
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 12:38:23.808356  - symbol_list1 took  2.1639373302459717 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:39:05.985822  - symbol_list1 took  1.5050761699676514 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:39:47.493542  - symbol_list1 took  1.5930194854736328 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# 2022-12-06 12:40:29.098128  - symbol_list1 took  1.8027324676513672 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:41:10.904256  - symbol_list1 took  1.7659122943878174 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  AAPL
# ALL CONDITIONS FOR BUY STOCK MET FOR  COIN
# 2022-12-06 12:41:52.682246  - symbol_list1 took  1.951838493347168 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:42:34.650024  - symbol_list1 took  1.4980764389038086 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:43:16.153223  - symbol_list1 took  1.677969217300415 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:43:57.841714  - symbol_list1 took  1.6649739742279053 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:44:39.509485  - symbol_list1 took  1.6110107898712158 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:45:21.125944  - symbol_list1 took  1.7274539470672607 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:46:02.858413  - symbol_list1 took  1.6140034198760986 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:46:44.480145  - symbol_list1 took  1.5780296325683594 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:47:26.066825  - symbol_list1 took  1.573033332824707 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:48:07.644958  - symbol_list1 took  1.558042287826538 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:48:49.208898  - symbol_list1 took  1.4790875911712646 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:49:30.692415  - symbol_list1 took  1.5870251655578613 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 12:50:12.283482  - symbol_list1 took  1.8358724117279053 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 12:50:54.133586  - symbol_list1 took  2.040743112564087 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  COIN
# 2022-12-06 12:51:36.178224  - symbol_list1 took  1.8848392963409424 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  SPY
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMZN
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# 2022-12-06 12:52:18.077557  - symbol_list1 took  2.5964009761810303 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NFLX
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# Extra data: line 1 column 101 (char 100)
# CCL
# list indices must be integers or slices, not str
# 2022-12-06 12:53:00.690512  - symbol_list1 took  16.81028938293457 seconds.
# **************************************************************
# Traceback (most recent call last):
#   File "C:\Users\VivekP\AppData\Local\Temp\ipykernel_3124\3314301234.py", line 68, in getStrategyResult
#     bidPrice = round((quote['Bid']), 2)
# TypeError: list indices must be integers or slices, not str
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NFLX
# 2022-12-06 12:53:57.504262  - symbol_list1 took  3.285978078842163 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMD
# ALL CONDITIONS FOR SELL STOCK MET FOR  AMZN
# 2022-12-06 12:54:40.808324  - symbol_list1 took  2.4316956996917725 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:55:23.251296  - symbol_list1 took  1.8818414211273193 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:56:05.145735  - symbol_list1 took  1.5450587272644043 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  AAPL
# 2022-12-06 12:56:46.700675  - symbol_list1 took  2.7123324871063232 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
# ALL CONDITIONS FOR SELL STOCK MET FOR  MSFT
# 2022-12-06 12:57:29.430885  - symbol_list1 took  2.474734306335449 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:58:11.909967  - symbol_list1 took  1.6230051517486572 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 12:58:53.543083  - symbol_list1 took  1.702951431274414 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  COIN
# ALL CONDITIONS FOR BUY STOCK MET FOR  LABU
# ALL CONDITIONS FOR BUY STOCK MET FOR  CCL
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# 2022-12-06 12:59:35.251426  - symbol_list1 took  2.4415688514709473 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:00:17.711361  - symbol_list1 took  1.605010986328125 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# 2022-12-06 13:00:59.332024  - symbol_list1 took  2.2306277751922607 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# ALL CONDITIONS FOR SELL STOCK MET FOR  CCL
# ALL CONDITIONS FOR SELL STOCK MET FOR  SHOP
# 2022-12-06 13:01:41.575132  - symbol_list1 took  2.3632125854492188 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:02:23.953150  - symbol_list1 took  1.5620386600494385 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:03:05.517948  - symbol_list1 took  1.5620391368865967 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  AMD
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 13:03:47.097266  - symbol_list1 took  1.9158241748809814 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:04:29.019857  - symbol_list1 took  1.7289385795593262 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:05:10.754815  - symbol_list1 took  1.4391155242919922 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:05:52.204111  - symbol_list1 took  1.669973373413086 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:06:33.884707  - symbol_list1 took  1.6349914073944092 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:07:15.530869  - symbol_list1 took  1.7279353141784668 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:07:57.275211  - symbol_list1 took  1.6469900608062744 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# Last Date was  12-05-2022
# Date was MISMATCH. Had to reset BARSBACK for  AMD
# Dataframe is ACCURATE after resetting barsBack
# 2022-12-06 13:08:38.926303  - symbol_list1 took  3.1730477809906006 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  TSLA
# 2022-12-06 13:09:22.103601  - symbol_list1 took  1.6969645023345947 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:10:03.807952  - symbol_list1 took  1.6179993152618408 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:10:45.437551  - symbol_list1 took  1.7019538879394531 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  CCL
# 2022-12-06 13:11:27.156221  - symbol_list1 took  2.345557451248169 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 13:12:09.505554  - symbol_list1 took  1.6140069961547852 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# 2022-12-06 13:12:51.127104  - symbol_list1 took  1.6769685745239258 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  NVDA
# ALL CONDITIONS FOR BUY STOCK MET FOR  SHOP
# ALL CONDITIONS FOR BUY STOCK MET FOR  PLUG
# 2022-12-06 13:13:32.818020  - symbol_list1 took  2.0747692584991455 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  MSFT
# 2022-12-06 13:14:14.903332  - symbol_list1 took  2.2231194972991943 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  MSFT
# 2022-12-06 13:14:57.137848  - symbol_list1 took  2.0502753257751465 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  TSLA
# ALL CONDITIONS FOR SELL STOCK MET FOR  NVDA
# ALL CONDITIONS FOR SELL STOCK MET FOR  LABU
# 2022-12-06 13:15:39.198461  - symbol_list1 took  2.212637424468994 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR SELL STOCK MET FOR  PLUG
# 2022-12-06 13:16:21.417954  - symbol_list1 took  2.4894676208496094 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  LABU
# 2022-12-06 13:17:03.914226  - symbol_list1 took  1.5788030624389648 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  SPY
# ALL CONDITIONS FOR BUY STOCK MET FOR  AMZN
# ALL CONDITIONS FOR BUY STOCK MET FOR  LABU
# 2022-12-06 13:17:45.510566  - symbol_list1 took  2.123694658279419 seconds.
# **************************************************************
# ['LABU', 'SPY', 'COIN', 'SHOP', 'TSLA', 'PLUG', 'NVDA', 'AMD', 'CCL', 'NFLX', 'AAPL', 'MSFT', 'AMZN']
# ALL CONDITIONS FOR BUY STOCK MET FOR  TSLA
# ALL CONDITIONS FOR BUY STOCK MET FOR  COIN
# ALL CONDITIONS FOR BUY STOCK MET FOR  NVDA
# 2022-12-06 13:18:27.649179  - symbol_list1 took  2.267620086669922 seconds.
# **************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 82>()
#     101  print(now, ' - symbol_list1 took ', time.time()-start, 'seconds.')
#     103  print("**************************************************************")
# --> 104  time.sleep(40)
#     107  '''
#     108
#     109  buystrategy,sellstrategy,buylong,buyshort,buycall,buyput = get_Trade_Signals_fromDB()
#    (...)
#     145
#     146 '''
#
# KeyboardInterrupt:
